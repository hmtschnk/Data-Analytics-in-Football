# %%
# IMPORT LIBRARIES

import numpy as np
import pandas as pd

# %%
# ACQUIRE DATASETS FROM football-data.co.uk

# England
eng11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1011/E0.csv")
eng12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1112/E0.csv")
eng13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/E0.csv")
eng14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/E0.csv")
eng15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E0.csv")
eng16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E0.csv")
eng17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E0.csv")
eng18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E0.csv")
eng19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E0.csv")
eng20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E0.csv")
eng21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E0.csv")

# Spain
esp11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1011/SP1.csv")
esp12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1112/SP1.csv")
esp13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SP1.csv")
esp14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SP1.csv")
esp15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP1.csv")
esp16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP1.csv")
esp17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP1.csv")
esp18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP1.csv")
esp19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP1.csv")
esp20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP1.csv")
esp21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP1.csv")

# France
fra11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1011/F1.csv")
fra12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1112/F1.csv")
fra13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/F1.csv")
fra14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/F1.csv")
fra15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F1.csv")
fra16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F1.csv")
fra17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F1.csv")
fra18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F1.csv")
fra19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F1.csv")
fra20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F1.csv")
fra21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F1.csv")

# Germany
deu11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1011/D1.csv")
deu12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1112/D1.csv")
deu13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/D1.csv")
deu14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/D1.csv")
deu15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D1.csv")
deu16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D1.csv")
deu17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D1.csv")
deu18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D1.csv")
deu19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D1.csv")
deu20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D1.csv")
deu21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D1.csv")

# Italy
ita11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1011/I1.csv")
ita12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1112/I1.csv")
ita13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/I1.csv")
ita14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/I1.csv")
ita15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I1.csv")
ita16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I1.csv")
ita17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I1.csv")
ita18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I1.csv")
ita19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I1.csv")
ita20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I1.csv")
ita21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I1.csv")

# %%
eng21.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  12/09/2020  12:30          Fulham      Arsenal     0     3   A     0
# 1  E0  12/09/2020  15:00  Crystal Palace  Southampton     1     0   H     1
# 2  E0  12/09/2020  17:30       Liverpool        Leeds     4     3   H     3
# 3  E0  12/09/2020  20:00        West Ham    Newcastle     0     2   A     0
# 4  E0  13/09/2020  14:00       West Brom    Leicester     0     3   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84  0.75      2.01      1.89   2.02   1.91     2.13
# 1     0  ...     1.70  0.25      1.78      2.13   1.79   2.17     1.85
# 2     2  ...     2.62 -1.50      1.85      2.05   1.85   2.08     1.90
# 3     0  ...     1.92 -0.50      2.03      1.87   2.04   1.88     2.09
# 4     0  ...     1.73  0.25      1.92      1.98   1.93   1.99     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# ...
